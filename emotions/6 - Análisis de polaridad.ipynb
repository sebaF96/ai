# %% [markdown]
# # Análisis de Polaridad
#
# En análisis de polaridad consiste en otorgar un valor numérico (positivo o negativo) a diferentes palabras o expresiones asociadas a su uso más común con respecto a las emociones.
#
# ### Vader Sentiment Analysis
# VADER Sentiment Analysis es una herramienta de analisis de sentimiento basada en <b>reglas léxicas</b>. Funciona a partir de un conjunto de palabras o <b>lexicón</b> cuyo significado semántico está asociado mayormente a expresiones positivas o negativas. Al analizar una oración Vader tiene en cuenta todas las palabras que puedan afectar el sentimiento expresado y da como resultado un analisis del porcentaje estimado de expresiones positivas y negativas.
#
# Las palabras reconocidas por Vader tienen asociadas un <b>valor numérico</b> positivo o negativo dependiendo de la emoción que expresan. Si una palabra no se encuentra en la lista de palabras valoradas esta no se tiene en cuenta para la evaluación.
#
# Al realizar un análisis de sentimiento sobre un texto Vader devuelve 4 valores
# - Porcentaje del contenido que cae dentro de la clasificación positiva
# - Porcentaje del contenido que cae dentro de la clasificación neutral
# - Porcentaje del contenido que cae dentro de la clasificación negativa
# - Puntuación compuesta: Total de los valores obtenidos normalizado entre 1 y -1

# %%
import nltk
nltk.download('vader_lexicon')
#conda install -c conda-forge vadersentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/santiago/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ### Obtener polaridad

# %%
sentence = "This is a great product! Very good quality"
# Instanciar Analizador
sentiment_analyzer = SentimentIntensityAnalyzer()
# Analizar polaridad de la oración
analisis = sentiment_analyzer.polarity_scores(sentence)
print(analisis)
# Out:
# {'neg': 0.0, 'neu': 0.442, 'pos': 0.558, 'compound': 0.8217}

# %% [markdown]
# ## Ejemplo

# %%
import pandas as pd
df = pd.read_csv("movie-reviews.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9c93650e32dc> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("movie-reviews.csv")
#       3 df
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'movie-reviews.csv'

# %%
df["negative"] = ""
df["neutral"] = ""
df["positive"] = ""
df["result"] = ""
for index, row in df.iterrows():
    #Analizar cada review
    analisis = sentiment_analyzer.polarity_scores(row['reviews'])
    row["negative"] = analisis["neg"]
    row["neutral"] = analisis["neu"]
    row["positive"] = analisis["pos"]
    # Evaluar que valores se considerarán positivo o negativo
    if analisis['compound'] >= 0 :
        row["result"] = "Positive"
    elif analisis['compound'] <=  0 :
        row["result"] = "Negative"
    else :
        row["result"] = "Neutral"
df

# %% [markdown]
# # Ejercicio
#
# - Obtener de la API Tweets que no sean retweet y que contengan el hashtag #SpiderMan2 en inglés.
# - Realizar limpieza en los datos
# - Evaluar la polaridad

# %%
import requests
import os
from dotenv import load_dotenv
import pandas as pd
import string
from nltk.tokenize import TweetTokenizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

import nltk
nltk.download('vader_lexicon')
#conda install -c conda-forge vadersentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
url = "https://api.twitter.com/2/tweets/search/recent"
# Cargar valores del archivo .env en las variables de entorno
load_dotenv()
# Cargar valor del token a variable
bearer_token = os.environ.get("BEARER_TOKEN")
sentiment_analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/santiago/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
params = {
    'query': '#FarCry6  lang:en -is:retweet',
    'tweet.fields':'created_at',
    'max_results':40
}
headers = {
    "Authorization": f"Bearer {bearer_token}",
    
# 28  Far Cry® 6\nMontero Justicia (BRONZE)\n#PlaySt...
# 29  Finding news takes time! If you like what you ...
# 30  Far Cry® 6\nMontero Justicia (BRONZE)\n#PlaySt...
# 31  Far Cry® 6\nDo It Yourself (BRONZE)\n#PlayStat...
# 32  We're getting off the island ladies and gentle...
# 33  Far Cry® 6\nDo It Yourself (BRONZE)\n#PlayStat...
# 34  This little guy #Chorizo #PS5Share, #FarCry6 h...
# 35  :-)  ADULTS ONLY!!!  &lt;&lt;First play throug...
# 36  Blessing your feed with your daily dose of adr...
# 37  🔥 Far Cry 6 - Meet the Actors of FC6's Voice C...
# 38  My friend @GamingMihailov showed me who is the...
# 39  We out here and we're playing #FarCry6 at 3pm ...

# %%
URL_REGEX = r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))"
MENTIONS_REGEX = r"(?<=^|(?<=[^a-zA-Z0-9-_\.]))@([A-Za-z]+[A-Za-z0-9-_]+)"
HASHTAG_REGEX = r"#"



df["text"].replace(URL_REGEX,'',regex=True, inplace = True)
df["text"].replace(MENTIONS_REGEX,'',regex=True, inplace = True)
df["text"].replace(HASHTAG_REGEX,'',regex=True, inplace = True)
df["text"].replace(r"[^A-Za-z0-9 | \n]+",' ',regex=True, inplace = True)
df["text"].replace(r"\t",' ',regex=True, inplace = True)
df["text"].replace('[{}]'.format(string.punctuation),' ',regex=True, inplace = True)
df["text"].replace(r"\n",'',regex=True, inplace = True)

df["text"] = df["text"].str.lower()
df
df = df.drop('created_at', 1)
df = df.drop('id', 1)

# %%
df["negative"] = ""
df["neutral"] = ""
df["positive"] = ""
df["result"] = ""
for index, row in df.iterrows():
    #Analizar cada review
    analisis = sentiment_analyzer.polarity_scores(row['text'])
    row["negative"] = analisis["neg"]
    row["neutral"] = analisis["neu"]
    row["positive"] = analisis["pos"]
    # Evaluar que valores se considerarán positivo o negativo
    if analisis['compound'] >= 0.7 :
        row["result"] = "Positive"
    elif analisis['compound'] <=  0.3 :
        row["result"] = "Negative"
    else :
        row["result"] = "Neutral"


df
# Out:
#                                                  text negative neutral  \
# 0   farcry6 assassinscreed leap of faith  or so we...      0.0   0.797
# 1   highest point of the map  farcry6  farcrycontest       0.0     1.0
# 2   join us on  from 8pm tonight  for our review d...    0.108   0.732
# 3                           beautiful farcry6 stadia       0.0   0.339
# 4   gameawards best performance of 2021 has gotta ...      0.0   0.826
# 5                            jackpot  farcry6 stadia       0.0     1.0
# 6   will the real slim shady please stand up   far...      0.0   0.796
# 7        scenery looking beautiful as ever   farcry6       0.0   0.562
# 8                  wtf 2    far cry 6 farcry6 farcry      0.58    0.42
# 9                               it has begun farcry6       0.0     1.0
# 10  far cry 6 gameplay 4k ultra graphics part 1   ...    0.129   0.871
# 11                    with my bro  farcry6 xboxshare       0.0     1.0
# 12  sad times farcry6 gaming screenshots virtualph...    0.256   0.744
# 13  say hi to  coingecko  amp  cmc     floki eth m...      0.0     1.0
# 14  10 games you can also adventure on an island l...    0.164   0.582
# 15      feels like home   farcry6 virtualphotography       0.0   0.615
# 16  far cry 6 sold 50 905 physical units in its de...    0.079   0.814
# 17    if i win  can i also have chorizo to carry i...      0.0   0.787
# 18  hey come on over and say a big happy birthday ...      0.0   0.775
# 19      this game is ridiculously photogenic farcry6     0.324   0.676
# 20     i played farcry6 so you don t have to  farcry       0.0   0.789
# 21                            this looks fab  farcry6      0.0     0.5
# 22                       chicharron the chad farcry6       0.0     1.0
# 23  urban life in farcry6ps5   farcrycontest   vpr...      0.0     1.0
# 24  still haven t set up an internet plan after th...    0.085   0.615
# 25      havana is playing in a car in farcry6 la amo       0.0   0.833
# 26  hay who played the  6    or who saw the gamepl...      0.0   0.907
# 27                 ps5share  farcry6 what the f  lol       0.0   0.641
# 28  far cry  6montero justicia  bronze playstation...    0.307   0.693
# 29  finding news takes time  if you like what you ...    0.057   0.483
# 30  far cry  6montero justicia  bronze playstation...    0.307   0.693
# 31  far cry  6do it yourself  bronze playstationtr...    0.279   0.721
# 32  we re getting off the island ladies and gentle...    0.154   0.846
# 33  far cry  6do it yourself  bronze playstationtr...    0.279   0.721
# 34         this little guy chorizo ps5share  farcry6       0.0     1.0
# 35     adults only    lt lt first play through  ol...      0.0   0.732
# 36  blessing your feed with your daily dose of adr...      0.0   0.738
# 37    far cry 6   meet the actors of fc6 s voice c...    0.097   0.903
# 38  my friend  showed me who is the rooster around...      0.0   0.775
# 39  we out here and we re playing farcry6 at 3pm o...      0.0   0.758
#
#    positive    result
# 0     0.203   Neutral
# 1       0.0  Negative
# 2      0.16  Negative
# 3     0.661   Neutral
# 4     0.174   Neutral
# 5       0.0  Negative
# 6     0.204   Neutral
# 7     0.438   Neutral
# 8       0.0  Negative
# 9       0.0  Negative
# 10      0.0  Negative
# 11      0.0  Negative
# 12      0.0  Negative
# 13      0.0  Negative
# 14    0.254  Negative
# 15    0.385   Neutral
# 16    0.107  Negative
# 17    0.213   Neutral
# 18    0.225  Positive
# 19      0.0  Negative
# 20    0.211   Neutral
# 21      0.5   Neutral
# 22      0.0  Negative
# 23      0.0  Negative
# 24      0.3  Positive
# 25    0.167  Negative
# 26    0.093   Neutral
# 27    0.359   Neutral
# 28      0.0  Negative
# 29     0.46  Positive
# 30      0.0  Negative
# 31      0.0  Negative
# 32      0.0  Negative
# 33      0.0  Negative
# 34      0.0  Negative
# 35    0.268   Neutral
# 36    0.262   Neutral
# 37      0.0  Negative
# 38    0.225   Neutral
# 39    0.242   Neutral

# %%
# Tokenizar

tt = TweetTokenizer()

tokenized_text = df['text'].apply(tt.tokenize)
df["tokenized_text"] = tokenized_text
df
# Out:
#                                                  text negative neutral  \
# 0   farcry6 assassinscreed leap of faith  or so we...      0.0   0.797
# 1   highest point of the map  farcry6  farcrycontest       0.0     1.0
# 2   join us on  from 8pm tonight  for our review d...    0.108   0.732
# 3                           beautiful farcry6 stadia       0.0   0.339
# 4   gameawards best performance of 2021 has gotta ...      0.0   0.826
# 5                            jackpot  farcry6 stadia       0.0     1.0
# 6   will the real slim shady please stand up   far...      0.0   0.796
# 7        scenery looking beautiful as ever   farcry6       0.0   0.562
# 8                  wtf 2    far cry 6 farcry6 farcry      0.58    0.42
# 9                               it has begun farcry6       0.0     1.0
# 10  far cry 6 gameplay 4k ultra graphics part 1   ...    0.129   0.871
# 11                    with my bro  farcry6 xboxshare       0.0     1.0
# 12  sad times farcry6 gaming screenshots virtualph...    0.256   0.744
# 13  say hi to  coingecko  amp  cmc     floki eth m...      0.0     1.0
# 14  10 games you can also adventure on an island l...    0.164   0.582
# 15      feels like home   farcry6 virtualphotography       0.0   0.615
# 16  far cry 6 sold 50 905 physical units in its de...    0.079   0.814
# 17    if i win  can i also have chorizo to carry i...      0.0   0.787
# 18  hey come on over and say a big happy birthday ...      0.0   0.775
# 19      this game is ridiculously photogenic farcry6     0.324   0.676
# 20     i played farcry6 so you don t have to  farcry       0.0   0.789
# 21                            this looks fab  farcry6      0.0     0.5
# 22                       chicharron the chad farcry6       0.0     1.0
# 23  urban life in farcry6ps5   farcrycontest   vpr...      0.0     1.0
# 24  still haven t set up an internet plan after th...    0.085   0.615
# 25      havana is playing in a car in farcry6 la amo       0.0   0.833
# 26  hay who played the  6    or who saw the gamepl...      0.0   0.907
# 27                 ps5share  farcry6 what the f  lol       0.0   0.641
# 28  far cry  6montero justicia  bronze playstation...    0.307   0.693
# 29  finding news takes time  if you like what you ...    0.057   0.483
# 30  far cry  6montero justicia  bronze playstation...    0.307   0.693
# 31  far cry  6do it yourself  bronze playstationtr...    0.279   0.721
# 32  we re getting off the island ladies and gentle...    0.154   0.846
# 33  far cry  6do it yourself  bronze playstationtr...    0.279   0.721
# 34         this little guy chorizo ps5share  farcry6       0.0     1.0
# 35     adults only    lt lt first play through  ol...      0.0   0.732
# 36  blessing your feed with your daily dose of adr...      0.0   0.738
# 37    far cry 6   meet the actors of fc6 s voice c...    0.097   0.903
# 38  my friend  showed me who is the rooster around...      0.0   0.775
# 39  we out here and we re playing farcry6 at 3pm o...      0.0   0.758
#
#    positive    result                                     tokenized_text
# 0     0.203   Neutral  [farcry, 6, assassinscreed, leap, of, faith, o...
# 1       0.0  Negative  [highest, point, of, the, map, farcry, 6, farc...
# 2      0.16  Negative  [join, us, on, from, 8p, m, tonight, for, our,...
# 3     0.661   Neutral                     [beautiful, farcry, 6, stadia]
# 4     0.174   Neutral  [gameawards, best, performance, of, 2021, has,...
# 5       0.0  Negative                       [jackpot, farcry, 6, stadia]
# 6     0.204   Neutral  [will, the, real, slim, shady, please, stand, ...
# 7     0.438   Neutral  [scenery, looking, beautiful, as, ever, farcry...
# 8       0.0  Negative           [wtf, 2, far, cry, 6, farcry, 6, farcry]
# 9       0.0  Negative                        [it, has, begun, farcry, 6]
# 10      0.0  Negative  [far, cry, 6, gameplay, 4k, ultra, graphics, p...
# 11      0.0  Negative              [with, my, bro, farcry, 6, xboxshare]
# 12      0.0  Negative  [sad, times, farcry, 6, gaming, screenshots, v...
# 13      0.0  Negative  [say, hi, to, coingecko, amp, cmc, floki, eth,...
# 14    0.254  Negative  [10, games, you, can, also, adventure, on, an,...
# 15    0.385   Neutral  [feels, like, home, farcry, 6, virtualphotogra...
# 16    0.107  Negative  [far, cry, 6, sold, 50, 905, physical, units, ...
# 17    0.213   Neutral  [if, i, win, can, i, also, have, chorizo, to, ...
# 18    0.225  Positive  [hey, come, on, over, and, say, a, big, happy,...
# 19      0.0  Negative  [this, game, is, ridiculously, photogenic, far...
# 20    0.211   Neutral  [i, played, farcry, 6, so, you, don, t, have, ...
# 21      0.5   Neutral                      [this, looks, fab, farcry, 6]
# 22      0.0  Negative                 [chicharron, the, chad, farcry, 6]
# 23      0.0  Negative  [urban, life, in, farcry, 6ps5, farcrycontest,...
# 24      0.3  Positive  [still, haven, t, set, up, an, internet, plan,...
# 25    0.167  Negative  [havana, is, playing, in, a, car, in, farcry, ...
# 26    0.093   Neutral  [hay, who, played, the, 6, or, who, saw, the, ...
# 27    0.359   Neutral           [ps5share, farcry, 6, what, the, f, lol]
# 28      0.0  Negative  [far, cry, 6montero, justicia, bronze, playsta...
# 29     0.46  Positive  [finding, news, takes, time, if, you, like, wh...
# 30      0.0  Negative  [far, cry, 6montero, justicia, bronze, playsta...
# 31      0.0  Negative  [far, cry, 6do, it, yourself, bronze, playstat...
# 32      0.0  Negative  [we, re, getting, off, the, island, ladies, an...
# 33      0.0  Negative  [far, cry, 6do, it, yourself, bronze, playstat...
# 34      0.0  Negative  [this, little, guy, chorizo, ps5share, farcry, 6]
# 35    0.268   Neutral  [adults, only, lt, lt, first, play, through, o...
# 36    0.262   Neutral  [blessing, your, feed, with, your, daily, dose...
# 37      0.0  Negative  [far, cry, 6, meet, the, actors, of, fc6, s, v...
# 38    0.225   Neutral  [my, friend, showed, me, who, is, the, rooster...
# 39    0.242   Neutral  [we, out, here, and, we, re, playing, farcry, ...

# %%
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))

def stop_func(tokenized_text: list) -> list:
    no_stopwords_data = []
    for x in tokenized_text:
        if x.lower() not in stop_words:
            no_stopwords_data.append(word)
    return no_stopwords_data


positive = []
negative = []
neutral = []
for index, row in df.iterrows():
      if row["result"] == "Positive":
            positive.extend(row["tokenized_text"])      
stop_func(positive)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-f75e673cb050> in <module>
#      16       if row["result"] == "Positive":
#      17             positive.extend(row["tokenized_text"])
# ---> 18 stop_func(positive)
#
# <ipython-input-60-f75e673cb050> in stop_func(tokenized_text)
#       5     no_stopwords_data = []
#       6     for x in tokenized_text:
# ----> 7         if x.lower() not in stop_words:
#       8             no_stopwords_data.append(word)
#       9     return no_stopwords_data
#
# TypeError: argument of type 'function' is not iterable
