# %% [markdown]
# # Análisis de Polaridad
#
# En análisis de polaridad consiste en otorgar un valor numérico (positivo o negativo) a diferentes palabras o expresiones asociadas a su uso más común con respecto a las emociones.
#
# ### Vader Sentiment Analysis
# VADER Sentiment Analysis es una herramienta de analisis de sentimiento basada en <b>reglas léxicas</b>. Funciona a partir de un conjunto de palabras o <b>lexicón</b> cuyo significado semántico está asociado mayormente a expresiones positivas o negativas. Al analizar una oración Vader tiene en cuenta todas las palabras que puedan afectar el sentimiento expresado y da como resultado un analisis del porcentaje estimado de expresiones positivas y negativas.
#
# Las palabras reconocidas por Vader tienen asociadas un <b>valor numérico</b> positivo o negativo dependiendo de la emoción que expresan. Si una palabra no se encuentra en la lista de palabras valoradas esta no se tiene en cuenta para la evaluación.
#
# Al realizar un análisis de sentimiento sobre un texto Vader devuelve 4 valores
# - Porcentaje del contenido que cae dentro de la clasificación positiva
# - Porcentaje del contenido que cae dentro de la clasificación neutral
# - Porcentaje del contenido que cae dentro de la clasificación negativa
# - Puntuación compuesta: Total de los valores obtenidos normalizado entre 1 y -1

# %%
# conda install -c conda-forge vadersentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# ### Obtener polaridad

# %%
sentence = "This is a great product! Very good quality"
# Instanciar Analizador
sentiment_analyzer = SentimentIntensityAnalyzer()
# Analizar polaridad de la oración
analisis = sentiment_analyzer.polarity_scores(sentence)
print(analisis)
# Out:
# {'neg': 0.0, 'neu': 0.442, 'pos': 0.558, 'compound': 0.8217}

# %% [markdown]
# ## Ejemplo

# %%
import pandas as pd

df = pd.read_csv("movie-reviews.csv")
df
# Out:
#                                              reviews
# 0  Excellent movie. The acting was great and it i...
# 1               A bit boring at first but enjoyable.
# 2    Very boring. You cant tell it has a low budget.
# 3                I loved it! Best movie of the year!
# 4  The special effects looked cheap and the plot ...
# 5  The actors did a good job but the script is te...
# 6                                Boring. So boring.
# 7                     Not the worst movie I've seen
# 8                                   A waste of time

# %%
df["negative"] = ""
df["neutral"] = ""
df["positive"] = ""
df["result"] = ""
for index, row in df.iterrows():
    # Analizar cada review
    analisis = sentiment_analyzer.polarity_scores(row["reviews"])
    row["negative"] = analisis["neg"]
    row["neutral"] = analisis["neu"]
    row["positive"] = analisis["pos"]
    # Evaluar que valores se considerarán positivo o negativo
    if analisis["compound"] >= 0:
        row["result"] = "Positive"
    elif analisis["compound"] <= 0:
        row["result"] = "Negative"
    else:
        row["result"] = "Neutral"
df
# Out:
#                                              reviews negative neutral  \
# 0  Excellent movie. The acting was great and it i...      0.0   0.469
# 1               A bit boring at first but enjoyable.    0.157   0.476
# 2    Very boring. You cant tell it has a low budget.     0.37    0.63
# 3                I loved it! Best movie of the year!      0.0   0.409
# 4  The special effects looked cheap and the plot ...      0.0   0.803
# 5  The actors did a good job but the script is te...    0.275   0.596
# 6                                Boring. So boring.      0.83    0.17
# 7                     Not the worst movie I've seen       0.0   0.603
# 8                                   A waste of time     0.483   0.517
#
#   positive    result
# 0    0.531  Positive
# 1    0.367  Positive
# 2      0.0  Negative
# 3    0.591  Positive
# 4    0.197  Positive
# 5    0.129  Negative
# 6      0.0  Negative
# 7    0.397  Positive
# 8      0.0  Negative

# %% [markdown]
# # Ejercicio
#
# - Obtener de la API Tweets que no sean retweet y que contengan el hashtag #SpiderMan2 en inglés.
# - Realizar limpieza en los datos
# - Evaluar la polaridad

# %%
import requests
import os
from dotenv import load_dotenv
import pandas as pd
import string
from nltk.tokenize import TweetTokenizer

# conda install -c conda-forge vadersentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

url = "https://api.twitter.com/2/tweets/search/recent"
# Cargar valores del archivo .env en las variables de entorno
load_dotenv()
# Cargar valor del token a variable
bearer_token = os.environ.get("BEARER_TOKEN")
sentiment_analyzer = SentimentIntensityAnalyzer()

# %%
params = {
    "query": "#FarCry6  lang:en -is:retweet",
    "tweet.fields": "created_at",
    "max_results": 40,
}
headers = {
    "Authorization": f"Bearer {bearer_token}",
    "User-Agent": "v2FullArchiveSearchPython",
}
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
print(response.json())
# Out:
# <Response [200]>
# {'data': [{'created_at': '2021-10-23T14:31:10.000Z', 'id': '1451919127665430534', 'text': 'Far Cry 4 - Part 15 https://t.co/QSSJEhPtsp via @YouTube #farcry #farcry2 #farcry3 #farcry4 #farcry5 #farcry6 #farcrynewdawn #farcryprimal #pc #xbox #xboxone #xbone #XboxSeriesS #XboxSeriesX #ps4 #ps4pro #ps5'}, {'created_at': '2021-10-23T14:29:51.000Z', 'id': '1451918800086048769', 'text': '#FarCry6 available for both PS4 and PS5.. We have a few copies remaining. \n\n#PS4: 480gh #PS5: 550gh \nKeep your orders coming 💯💯 https://t.co/r57ppW5cLN'}, {'created_at': '2021-10-23T14:26:39.000Z', 'id': '1451917994322546692', 'text': 'Far Cry 5\n\n@FarCrygame @Ubisoft @UbisoftMTL @UbisoftQuebec @UbisoftItalia #FarCry5 #FarCry #Ubisoft #FarCry6 #VirtualPhotography #VPGamers #GamerGram https://t.co/Kv38SsvA21'}, {'created_at': '2021-10-23T14:25:34.000Z', 'id': '1451917718240825351', 'text': 'Down by the waterside.\n\n#FarCry6 #VirtualPhotography #VGPUnite #XboxSeriesX https://t.co/xYPpkDAs3f'}, {'created_at': '2021-10-23T14:21:10.000Z', 'id': '1451916611926073344', 'text': 'I GOT A NEW PET GUYS #PS5Share #FarCry6 https://t.co/3QC8BmBmzi'}, {'created_at': '2021-10-23T14:20:05.000Z', 'id': '1451916340223221764', 'text': "Happy Saturday Morning, I'm ready to jump into some more Far Cry 6. Stream starts now, pull up. @TwitchRTSupport @twitchpromoters #stream #twitchtv #FarCry6 \nhttps://t.co/9Epjgrj5fr"}, {'created_at': '2021-10-23T14:17:54.000Z', 'id': '1451915791113277444', 'text': 'New episode up! Link in Bio!\n#FarCry6 #YouTuber #gaming https://t.co/5WF0hQus19'}, {'created_at': '2021-10-23T14:16:55.000Z', 'id': '1451915541766098953', 'text': "Now I'm going to play #FarCry6 to calm my nerves - Twitter is completely crazy today - I can't look at this content !! sorry #SUNOO  i just cant 😔\nbye guys https://t.co/H3PWbkkYtm"}, {'created_at': '2021-10-23T14:14:48.000Z', 'id': '1451915008993071104', 'text': '”Postcards from Yara”\n#FarCry6\xa0\xa0\xa0\xa0 \xa0\n0504\n@ubisoftanz @UbisoftCanada \n#ThePhotoMode \xa0#Gamer
# 28  hey all hope ur doing grerat going live with s...
# 29  FARCRY 6 - PART 5 | 1440p | RX 6900XT | RTX 30...
# 30  #SimpleShotSaturday from #FarCry6 \n#VGPUnite ...
# 31  Night Shift\n\n#SimpleShotSaturday #VirtualPho...
# 32  Far Cry® 6\nBeginner's Luck (BRONZE)\n#PlaySta...
# 33  Oh my god jesus christ #FarCry6 https://t.co/0...
# 34  Other options it would be nice to have would b...
# 35  Teaming up with lucky mama and taking on McKay...
# 36  #FarCry6 New toys\n#VGPUnite #WorldofVP #Gamer...
# 37  It might be nice if #Farcry6 could patch in so...
# 38  #FarCry6 meets #FarCryPrimal 😉\n#VGPUnite #Wor...
# 39  Yara is wonderful\n\n#FarCry6 https://t.co/wFe...

# %%
URL_REGEX = r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))"
MENTIONS_REGEX = r"(?<=^|(?<=[^a-zA-Z0-9-_\.]))@([A-Za-z]+[A-Za-z0-9-_]+)"
HASHTAG_REGEX = r"#"


df["text"].replace(URL_REGEX, "", regex=True, inplace=True)
df["text"].replace(MENTIONS_REGEX, "", regex=True, inplace=True)
df["text"].replace(HASHTAG_REGEX, "", regex=True, inplace=True)
df["text"].replace(r"[^A-Za-z0-9 | \n]+", " ", regex=True, inplace=True)
df["text"].replace(r"\t", " ", regex=True, inplace=True)
df["text"].replace("[{}]".format(string.punctuation), " ", regex=True, inplace=True)
df["text"].replace(r"\n", "", regex=True, inplace=True)

df["text"] = df["text"].str.lower()
df
df = df.drop("created_at", 1)
df = df.drop("id", 1)
# Out:
# <ipython-input-8-473f6f618575>:16: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop("created_at", 1)
# <ipython-input-8-473f6f618575>:17: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop("id", 1)

# %%
df["negative"] = ""
df["neutral"] = ""
df["positive"] = ""
df["result"] = ""
for index, row in df.iterrows():
    # Analizar cada review
    analisis = sentiment_analyzer.polarity_scores(row["text"])
    row["negative"] = analisis["neg"]
    row["neutral"] = analisis["neu"]
    row["positive"] = analisis["pos"]
    # Evaluar que valores se considerarán positivo o negativo
    if analisis["compound"] >= 0.7:
        row["result"] = "Positive"
    elif analisis["compound"] <= 0.3:
        row["result"] = "Negative"
    else:
        row["result"] = "Neutral"


df
# Out:
#                                                  text negative neutral  \
# 0   far cry 4   part 15  via  farcry farcry2 farcr...    0.124   0.876
# 1   farcry6 available for both ps4 and ps5  we hav...      0.0     1.0
# 2   far cry 5     farcry5 farcry ubisoft farcry6 v...    0.256   0.744
# 3   down by the waterside farcry6 virtualphotograp...      0.0     1.0
# 4              i got a new pet guys ps5share farcry6       0.0     1.0
# 5   happy saturday morning  i m ready to jump into...    0.118   0.665
# 6   new episode up  link in bio farcry6 youtuber g...      0.0     1.0
# 7   now i m going to play farcry6 to calm my nerve...    0.154   0.712
# 8    postcards from yara farcry6   0504  thephotom...      0.0     1.0
# 9   miami vice meets farcry6 click for full imagev...      0.0     1.0
# 10    i m starting   live on farcry6     wizebot t...      0.0     1.0
# 11   postcards from yara farcry6   0502   thephoto...      0.0     1.0
# 12           field trip will all my amigos   farcry6       0.0     1.0
# 13              farcry6 got some christmas trees           0.0     1.0
# 14  far cry  6liberdade  gold playstationtrophy ps...    0.341   0.659
# 15  this is awesome  only in a farcry game would y...      0.0   0.843
# 16  most overlooked qol feature in farcry6  slidin...    0.042   0.882
# 17             two for one special farcry6 xboxshare       0.0   0.649
# 18  lemme hop on farcry6 so i can shoot some folks...    0.182   0.818
# 19  returnal should be goty but next on my list fa...    0.084   0.555
# 20  esperanza  i m coming for you  ps5share  farcry6       0.0     1.0
# 21  even in yara  it s spooky season stadia virtua...      0.0     1.0
# 22  farcry 6   part 5   1440p   rx 6900xt   rtx 30...      0.0     1.0
# 23  farcry 6    part 4   1440p   live gameplay  vi...      0.0     1.0
# 24  farcry 6    part 3   1440p   live gameplay   r...      0.0     1.0
# 25  farcry 6    part 2   1440p   rx 6900xt   rtx 3...      0.0     1.0
# 26  farcry 6    part 1   1440p   rx 6900xt   rtx 3...      0.0     1.0
# 27  far cry 6  via  shooterfps farcry6 gaming rtx3...    0.279   0.721
# 28  hey all hope ur doing grerat going live with s...      0.0   0.707
# 29  farcry 6   part 5   1440p   rx 6900xt   rtx 30...      0.0     1.0
# 30  simpleshotsaturday from farcry6 vgpunite world...      0.0     1.0
# 31  night shiftsimpleshotsaturday virtualphotograp...      0.0     1.0
# 32  far cry  6beginner s luck  bronze playstationt...    0.237   0.534
# 33                    oh my god jesus christ farcry6       0.0   0.704
# 34  other options it would be nice to have would b...      0.0   0.909
# 35  teaming up with lucky mama and taking on mckay...      0.0   0.797
# 36  farcry6 new toysvgpunite worldofvp gamergram t...      0.0     1.0
# 37  it might be nice if farcry6 could patch in som...      0.0   0.801
# 38  farcry6 meets farcryprimal  vgpunite worldofvp...      0.0     1.0
# 39                          yara is wonderfulfarcry6       0.0     1.0
#
#    positive    result
# 0       0.0  Negative
# 1       0.0  Negative
# 2       0.0  Negative
# 3       0.0  Negative
# 4       0.0  Negative
# 5     0.217   Neutral
# 6       0.0  Negative
# 7     0.134  Negative
# 8       0.0  Negative
# 9       0.0  Negative
# 10      0.0  Negative
# 11      0.0  Negative
# 12      0.0  Negative
# 13      0.0  Negative
# 14      0.0  Negative
# 15    0.157   Neutral
# 16    0.076  Negative
# 17    0.351   Neutral
# 18      0.0  Negative
# 19     0.36  Positive
# 20      0.0  Negative
# 21      0.0  Negative
# 22      0.0  Negative
# 23      0.0  Negative
# 24      0.0  Negative
# 25      0.0  Negative
# 26      0.0  Negative
# 27      0.0  Negative
# 28    0.293  Positive
# 29      0.0  Negative
# 30      0.0  Negative
# 31      0.0  Negative
# 32    0.229  Negative
# 33    0.296  Negative
# 34    0.091   Neutral
# 35    0.203   Neutral
# 36      0.0  Negative
# 37    0.199  Positive
# 38      0.0  Negative
# 39      0.0  Negative

# %%
# Tokenizar

tt = TweetTokenizer()

tokenized_text = df["text"].apply(tt.tokenize)
df["tokenized_text"] = tokenized_text
df
# Out:
#                                                  text negative neutral  \
# 0   far cry 4   part 15  via  farcry farcry2 farcr...    0.124   0.876
# 1   farcry6 available for both ps4 and ps5  we hav...      0.0     1.0
# 2   far cry 5     farcry5 farcry ubisoft farcry6 v...    0.256   0.744
# 3   down by the waterside farcry6 virtualphotograp...      0.0     1.0
# 4              i got a new pet guys ps5share farcry6       0.0     1.0
# 5   happy saturday morning  i m ready to jump into...    0.118   0.665
# 6   new episode up  link in bio farcry6 youtuber g...      0.0     1.0
# 7   now i m going to play farcry6 to calm my nerve...    0.154   0.712
# 8    postcards from yara farcry6   0504  thephotom...      0.0     1.0
# 9   miami vice meets farcry6 click for full imagev...      0.0     1.0
# 10    i m starting   live on farcry6     wizebot t...      0.0     1.0
# 11   postcards from yara farcry6   0502   thephoto...      0.0     1.0
# 12           field trip will all my amigos   farcry6       0.0     1.0
# 13              farcry6 got some christmas trees           0.0     1.0
# 14  far cry  6liberdade  gold playstationtrophy ps...    0.341   0.659
# 15  this is awesome  only in a farcry game would y...      0.0   0.843
# 16  most overlooked qol feature in farcry6  slidin...    0.042   0.882
# 17             two for one special farcry6 xboxshare       0.0   0.649
# 18  lemme hop on farcry6 so i can shoot some folks...    0.182   0.818
# 19  returnal should be goty but next on my list fa...    0.084   0.555
# 20  esperanza  i m coming for you  ps5share  farcry6       0.0     1.0
# 21  even in yara  it s spooky season stadia virtua...      0.0     1.0
# 22  farcry 6   part 5   1440p   rx 6900xt   rtx 30...      0.0     1.0
# 23  farcry 6    part 4   1440p   live gameplay  vi...      0.0     1.0
# 24  farcry 6    part 3   1440p   live gameplay   r...      0.0     1.0
# 25  farcry 6    part 2   1440p   rx 6900xt   rtx 3...      0.0     1.0
# 26  farcry 6    part 1   1440p   rx 6900xt   rtx 3...      0.0     1.0
# 27  far cry 6  via  shooterfps farcry6 gaming rtx3...    0.279   0.721
# 28  hey all hope ur doing grerat going live with s...      0.0   0.707
# 29  farcry 6   part 5   1440p   rx 6900xt   rtx 30...      0.0     1.0
# 30  simpleshotsaturday from farcry6 vgpunite world...      0.0     1.0
# 31  night shiftsimpleshotsaturday virtualphotograp...      0.0     1.0
# 32  far cry  6beginner s luck  bronze playstationt...    0.237   0.534
# 33                    oh my god jesus christ farcry6       0.0   0.704
# 34  other options it would be nice to have would b...      0.0   0.909
# 35  teaming up with lucky mama and taking on mckay...      0.0   0.797
# 36  farcry6 new toysvgpunite worldofvp gamergram t...      0.0     1.0
# 37  it might be nice if farcry6 could patch in som...      0.0   0.801
# 38  farcry6 meets farcryprimal  vgpunite worldofvp...      0.0     1.0
# 39                          yara is wonderfulfarcry6       0.0     1.0
#
#    positive    result                                     tokenized_text
# 0       0.0  Negative  [far, cry, 4, part, 15, via, farcry, farcry, 2...
# 1       0.0  Negative  [farcry, 6, available, for, both, ps4, and, ps...
# 2       0.0  Negative  [far, cry, 5, farcry, 5, farcry, ubisoft, farc...
# 3       0.0  Negative  [down, by, the, waterside, farcry, 6, virtualp...
# 4       0.0  Negative   [i, got, a, new, pet, guys, ps5share, farcry, 6]
# 5     0.217   Neutral  [happy, saturday, morning, i, m, ready, to, ju...
# 6       0.0  Negative  [new, episode, up, link, in, bio, farcry, 6, y...
# 7     0.134  Negative  [now, i, m, going, to, play, farcry, 6, to, ca...
# 8       0.0  Negative  [postcards, from, yara, farcry, 6, 0504, theph...
# 9       0.0  Negative  [miami, vice, meets, farcry, 6, click, for, fu...
# 10      0.0  Negative  [i, m, starting, live, on, farcry, 6, wizebot,...
# 11      0.0  Negative  [postcards, from, yara, farcry, 6, 0502, theph...
# 12      0.0  Negative    [field, trip, will, all, my, amigos, farcry, 6]
# 13      0.0  Negative           [farcry, 6, got, some, christmas, trees]
# 14      0.0  Negative  [far, cry, 6liberdade, gold, playstationtrophy...
# 15    0.157   Neutral  [this, is, awesome, only, in, a, farcry, game,...
# 16    0.076  Negative  [most, overlooked, qol, feature, in, farcry, 6...
# 17    0.351   Neutral     [two, for, one, special, farcry, 6, xboxshare]
# 18      0.0  Negative  [lemme, hop, on, farcry, 6, so, i, can, shoot,...
# 19     0.36  Positive  [returnal, should, be, goty, but, next, on, my...
# 20      0.0  Negative  [esperanza, i, m, coming, for, you, ps5share, ...
# 21      0.0  Negative  [even, in, yara, it, s, spooky, season, stadia...
# 22      0.0  Negative  [farcry, 6, part, 5, 1440p, rx, 6900xt, rtx, 3...
# 23      0.0  Negative  [farcry, 6, part, 4, 1440p, live, gameplay, vi...
# 24      0.0  Negative  [farcry, 6, part, 3, 1440p, live, gameplay, rx...
# 25      0.0  Negative  [farcry, 6, part, 2, 1440p, rx, 6900xt, rtx, 3...
# 26      0.0  Negative  [farcry, 6, part, 1, 1440p, rx, 6900xt, rtx, 3...
# 27      0.0  Negative  [far, cry, 6, via, shooterfps, farcry, 6, gami...
# 28    0.293  Positive  [hey, all, hope, ur, doing, grerat, going, liv...
# 29      0.0  Negative  [farcry, 6, part, 5, 1440p, rx, 6900xt, rtx, 3...
# 30      0.0  Negative  [simpleshotsaturday, from, farcry, 6, vgpunite...
# 31      0.0  Negative  [night, shiftsimpleshotsaturday, virtualphotog...
# 32    0.229  Negative  [far, cry, 6beginner, s, luck, bronze, playsta...
# 33    0.296  Negative            [oh, my, god, jesus, christ, farcry, 6]
# 34    0.091   Neutral  [other, options, it, would, be, nice, to, have...
# 35    0.203   Neutral  [teaming, up, with, lucky, mama, and, taking, ...
# 36      0.0  Negative  [farcry, 6, new, toysvgpunite, worldofvp, game...
# 37    0.199  Positive  [it, might, be, nice, if, farcry, 6, could, pa...
# 38      0.0  Negative  [farcry, 6, meets, farcryprimal, vgpunite, wor...
# 39      0.0  Negative                     [yara, is, wonderfulfarcry, 6]

# %%
from nltk.corpus import stopwords

stopwords = set(stopwords.words("english"))


def stop_func(tokenized_text: list) -> list:
    no_stopwords_data = []
    for x in tokenized_text:
        if x.lower() not in stopwords:
            no_stopwords_data.append(x)
    return no_stopwords_data


positive = []
negative = []
neutral = []
for index, row in df.iterrows():
    if row["result"] == "Positive":
        positive.extend(row["tokenized_text"])
stop_func(positive)
# Out:
# ['returnal',
#  'goty',
#  'next',
#  'list',
#  'farcry',
#  '6',
#  'good',
#  'love',
#  'everything',
#  'check',
#  'fishing',
#  'serious',
#  'done',
#  'well',
#  'literally',
#  'relaxes',
#  'hey',
#  'hope',
#  'ur',
#  'grerat',
#  'going',
#  'live',
#  'farcry',
#  '6',
#  'hope',
#  'see',
#  'might',
#  'nice',
#  'farcry',
#  '6',
#  'could',
#  'patch',
#  'code',
#  'allowed',
#  'game',
#  'remember',
#  'turned',
#  'car',
#  'radio',
#  'least',
#  'vehicle',
#  'ideally',
#  'vehicles',
#  'amp',
#  'even',
#  'better',
#  'still',
#  'volume',
#  'slider',
#  'menus',
#  'including',
#  'entirely',
#  'would',
#  'ideal']
